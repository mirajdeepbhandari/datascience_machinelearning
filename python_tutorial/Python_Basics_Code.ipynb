# %% [markdown]
# # Python Basics
#
# ---
#
# ## 1. What Exactly is Python?
#
# **Python** is a **high-level**, **interpreted**, **general-purpose** programming language known for its simple and readable syntax. It was created by **Guido van Rossum** and first released in **1991**.
#
# ### Key Characteristics
#
# | Feature | Description |
# |--------|-------------|
# | **Dynamically typed** | You don't declare variable types; Python figures it out at runtime |
# | **Object-oriented** | Everything in Python is an object (numbers, strings, functions, etc.) |
# | **Cross-platform** | Runs on Windows, macOS, Linux, and even mobile devices |
# | **Free & Open-source** | Anyone can use, modify, and distribute it |
#
# ### Why is Python so Popular?
#
# - **Readable syntax** - looks almost like English
# - **Massive community support**
# - **Versatile** - used in Web Development, Data Science, AI/ML, Automation, Scripting, Game Development, IoT, and more
#
# ---
#
# ## 2. Python's Roots and Its Ecosystem
#
# ### The Python Ecosystem
#
# The ecosystem is what makes Python powerful.
#
# #### Package Manager
#
# - **pip** - Official Python package installer
# - **PyPI (Python Package Index)** - Repository with 400,000+ packages
#
# #### Popular Libraries by Domain
#
# | Domain | Libraries |
# |--------|-----------|
# | **Data Science** | NumPy, Pandas, Matplotlib, Seaborn |
# | **Machine Learning** | Scikit-learn, TensorFlow, PyTorch, Keras |
# | **Web Development** | Django, Flask, FastAPI |
# | **Web Scraping** | BeautifulSoup, Scrapy, Selenium |
# | **Automation** | Selenium, PyAutoGUI, Requests |
# | **GUI Development** | Tkinter, PyQt, Kivy |
# | **Game Development** | Pygame |
# | **Testing** | pytest, unittest |
#
# #### Development Tools
#
# - **IDEs**: PyCharm, VS Code, Spyder
# - **Notebooks**: Jupyter Notebook, Google Colab
# - **Virtual Environments**: venv, virtualenv, conda
# - **Code Formatters**: Black, autopep8
# - **Linters**: pylint, flake8
#
# #### Community
#
# - Python Software Foundation (PSF)
# - PyCon conferences worldwide
# - Stack Overflow, Reddit (r/Python), Discord servers

# %% [markdown]
# ## Is Python Compiled or Interpreted?
#
# Python is both **compiled** and **interpreted**.
#
# ### Step 1: Compilation
#
# Python converts source code (`.py`) into **bytecode** (`.pyc`).
#
# ### Step 2: Interpretation
#
# The Python Virtual Machine (PVM) interprets and executes the bytecode.
#
# ### Simple Summary
#
# ```text
# Python Code (.py)
#         ↓
#    Bytecode (.pyc)
#         ↓
# Python Virtual Machine (PVM)
#         ↓
#       Output
# ```
#
# ### Interview Answer
#
# Python is both compiled and interpreted. It first compiles the source code into bytecode and then the Python Virtual Machine (PVM) interprets and executes that bytecode.

# %% [markdown]
# # Python Basics - Hands-On Code Practice
#
# Welcome! This notebook contains practical code examples for Python beginners.
#
# **Topics Covered:**
# 1. Introduction to Python
# 2. Data Types & Variables
# 3. Input and Output Functions
# 4. format() Method, f-strings, & Escape Sequences
# 5. Basic Arithmetic & Operators
# 6. Type Casting, Type Checking & Validation
#
# ---
#
# **How to use this notebook:** Click on a code cell and press `Shift + Enter` to run it.

# %% [markdown]
# ## 1. Introduction - Your First Python Program
#
# Let's start with the classic 'Hello, World!' program.

# %%
# Your first Python program!
print("Hello, World!")
print("Welcome to Python programming!")
# Out:
# Hello, World!
# Welcome to Python programming!

# %%
# Check Python version
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %% [markdown]
# ---
# ## 2. Data Types & Variables
# `Variables are containers for storing data values.`
# ### 2.1 Creating Variables
#
# In Python, you create a variable by simply assigning a value using `=`.

# %% [markdown]
# A variable can have a short name (like `x` and `y`) or a more descriptive name (`age`, `carname`, `total_volume`).
#
# ## Rules for Python Variables
#
# - A variable name must start with a letter or the underscore character (`_`)
# - A variable name cannot start with a number
# - A variable name can only contain alphanumeric characters and underscores (`A–Z`, `a–z`, `0–9`, `_`)
# - Variable names are case-sensitive (`age`, `Age`, and `AGE` are three different variables)
# - A variable name cannot be any of the Python keywords

# %% [markdown]
# ## Legal Variable Names
#
# ```python
# myvar = "John"
# my_var = "John"
# _my_var = "John"
# myVar = "John"
# MYVAR = "John"
# myvar2 = "John"
# ```
#
# ## Illegal Variable Names
#
# ```python
# 2myvar = "John"    # Cannot start with a number
# my-var = "John"    # Hyphen (-) is not allowed
# my var = "John"    # Spaces are not allowed
# ```

# %%
# Creating variables
name = "Alice" #string
age = 25 # integer
height = 5.6 # float
is_student = True # boolean

print(name)
print(age)
print(height)
print(is_student)

print("My name is ", name, "and I am", age, "years old.")
print("My name is "+ name +" and I am "+ str(age) +" years old.")
# Out:
# Alice
# 25
# 5.6
# True
# My name is  Alice and I am 25 years old.
# My name is Alice and I am 25 years old.

# %% [markdown]
# ## 2.2 Data Types
#
# `Variables can store data of different types, and different types can do different things.`
#
# ### What is a Data Type?
#
# A **data type** is a classification that tells Python:
# - **What kind of value** a variable holds (text, number, true/false, etc.)
# - **How much memory** to allocate for it
# - **What operations** can be performed on it (e.g., you can add two numbers, but you can't divide two strings)
#
# Python is a **dynamically typed** language, meaning you don't need to declare the type of a variable - Python figures it out automatically based on the value you assign.
#
# ```python
# x = 5         # Python knows this is an int
# x = "Hello"   # Now Python knows this is a str
# ```
#
# ### Built-in Data Types in Python
#
# Python has several built-in data types, grouped into categories:
#
# | Category | Data Types |
# |----------|------------|
# | **Text Type** | `str` |
# | **Numeric Types** | `int`, `float`, `complex` |
# | **Sequence Types** | `list`, `tuple`, `range` |
# | **Mapping Type** | `dict` |
# | **Set Types** | `set`, `frozenset` |
# | **Boolean Type** | `bool` |
# | **Binary Types** | `bytes`, `bytearray`, `memoryview` |
# | **None Type** | `NoneType` |
#
# > In this lesson, we focus on the **core beginner data types**: `str`, `int`, `float`, `complex`, `bool`, and `None`. The others (lists, tuples, dicts, sets) will be covered in upcoming lessons.
#
# ### The `type()` Function
#
# Python provides a built-in function `type()` that returns the data type of any value or variable.
#
# **Syntax:**
# ```python
# type(value)
# ```
#
# This is super useful when you want to check what kind of data you're working with.
#
# ### Quick Overview of the Core Data Types
#
# | Data Type | Class Name | Example | Used For |
# |-----------|------------|---------|----------|
# | String | `str` | `"Hello"`, `'Python'` | Text, names, sentences |
# | Integer | `int` | `10`, `-50`, `2026` | Whole numbers (counting) |
# | Float | `float` | `3.14`, `-0.5`, `2.5e3` | Decimal numbers (measurements) |
# | Complex | `complex` | `3 + 4j` | Scientific & engineering calculations |
# | Boolean | `bool` | `True`, `False` | Yes/No, On/Off, conditions |
# | NoneType | `NoneType` | `None` | Absence of value (empty) |
#
# ### How Python Assigns a Data Type
#
# Python decides the data type based on the **value** you assign:
#
# | If value is... | Data type will be... |
# |----------------|----------------------|
# | Enclosed in quotes `" "` or `' '` | `str` |
# | A whole number (no decimal) | `int` |
# | A number with a decimal point | `float` |
# | A number with `j` at the end | `complex` |
# | `True` or `False` | `bool` |
# | `None` | `NoneType` |
#
# Let's see this in action with the `type()` function in the next cell.

# %%
# Out:
# miraj		bhandari

# %%
# Using type() to check the data type of different values

print("Value\t\tData Type")
print("-" * 35)
print("'Hello'\t\t", type("Hello"))
print("100\t\t", type(100))
print("3.14\t\t", type(3.14))
print("3 + 4j\t\t", type(3 + 4j))
print("True\t\t", type(True))
print("None\t\t", type(None))
# Out:
# Value		Data Type
# -----------------------------------
# 'Hello'		 <class 'str'>
# 100		 <class 'int'>
# 3.14		 <class 'float'>
# 3 + 4j		 <class 'complex'>
# True		 <class 'bool'>
# None		 <class 'NoneType'>

# %%
# Checking data type of variables

name = "Alice"          # str
age = 25                # int
height = 5.6            # float
z = 2 + 3j              # complex
is_student = True       # bool
address = None          # NoneType

print("name     =", name, "->", type(name))
print("age      =", age, "->", type(age))
print("height   =", height, "->", type(height))
print("z        =", z, "->", type(z))
print("student? =", is_student, "->", type(is_student))
print("address  =", address, "->", type(address))
# Out:
# name     = Alice -> <class 'str'>
# age      = 25 -> <class 'int'>
# height   = 5.6 -> <class 'float'>
# z        = (2+3j) -> <class 'complex'>
# student? = True -> <class 'bool'>
# address  = None -> <class 'NoneType'>

# %%
# Python is DYNAMICALLY TYPED - the same variable can hold different types
x = 10
print("x =", x, ", type =", type(x))

x = "Now I'm a string"
print("x =", x, ", type =", type(x))

x = 3.14
print("x =", x, ", type =", type(x))

x = True
print("x =", x, ", type =", type(x))
# Out:
# x = 10 , type = <class 'int'>
# x = Now I'm a string , type = <class 'str'>
# x = 3.14 , type = <class 'float'>
# x = True , type = <class 'bool'>

# %% [markdown]
# ### Why Data Types Matter
#
# Different data types support different operations. Knowing the type helps you avoid errors.
#
# | Operation | Works on | Example |
# |-----------|----------|---------|
# | `+` (addition) | numbers | `5 + 3 = 8` |
# | `+` (concatenation) | strings | `"Hi" + " there" = "Hi there"` |
# | `+` between str and int | NOT ALLOWED | `"Age: " + 25` -> Error! |
#
# Mixing incompatible types causes a `TypeError`. See the example below.

# %%
# Example of a TypeError - mixing string and integer with +
age_num = 25
age_str = "30"
sum_age = age_num + age_str  # This will raise a TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3 age_num = 25
#       4 age_str = "30"
# ----> 5 sum_age = age_num + age_str  # This will raise a TypeError
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Summary - Section 2.2
#
# - Python is **dynamically typed** - it figures out the type automatically.
# - Use the **`type()`** function to check the type of any value or variable.
# - The **core data types** for beginners are: `str`, `int`, `float`, `complex`, `bool`, `None`.
#
# Next, let's explore each of these data types in detail.

# %% [markdown]
# ### 2.2 String (`str`)
# Text data enclosed in quotes.

# %%
# Strings can use single, double, or triple quotes
single = 'Hello'
double = "World"
multi_line = """This is
a multi-line
string."""

print(single)
print(double)
print(multi_line)

# String concatenation with +
greeting = single + " " + double + "!"
print(greeting)

# String repetition with *
print("Ha" * 3)
# Out:
# Hello
# World
# This is
# a multi-line
# string.
# Hello World!
# HaHaHa

# %% [markdown]
# ### 2.3 Integer (`int`)
# Whole numbers - positive, negative, or zero.

# %%
age = 25
year = 2026
negative_num = -100
big_number = 1_000_000    # underscores improve readability

print(age)
print(year)
print(negative_num)
print(big_number)
print("Type of age:", type(age))
# Out:
# 25
# 2026
# -100
# 1000000
# Type of age: <class 'int'>

# %% [markdown]
# ### 2.4 Float (`float`)
# Numbers with a decimal point.

# %%
price = 99.99
pi = 3.14159
temperature = -5.5
scientific = 2.5e3   # 2.5 x 10^3 = 2500.0

print(price)
print(pi)
print(temperature)
print(scientific)
print("Type of pi:", type(pi))
# Out:
# 99.99
# 3.14159
# -5.5
# 2500.0
# Type of pi: <class 'float'>

# %% [markdown]
# ### 2.5 Complex (`complex`)
# Numbers with a real and imaginary part.

# %%
z = 3 + 4j
print("Complex number:", z)
print("Real part:", z.real)
print("Imaginary part:", z.imag)
print("Type:", type(z))

# Arithmetic with complex numbers
z1 = 2 + 3j
z2 = 1 - 1j
print("Sum:", z1 + z2)
# Out:
# Complex number: (3+4j)
# Real part: 3.0
# Imaginary part: 4.0
# Type: <class 'complex'>
# Sum: (3+2j)

# %% [markdown]
# ### 2.6 Boolean (`bool`)
# Truth values: `True` or `False` (capitalized!).

# %%
True - 1
False - 0

# %%
a= True
b= False
c= a+b
print(c)
# Out:
# 1

# %%
is_student = True
is_logged_in = False

print(is_student)
print(is_logged_in)
print("Type:", type(is_student))

# Booleans are actually integers!
print("True + True =", True + True)   # 2
print("False * 100 =", False * 100)   # 0
# Out:
# True
# False
# Type: <class 'bool'>
# True + True = 2
# False * 100 = 0

# %% [markdown]
# ### 2.7 NoneType (`None`)
# Represents the absence of a value.

# %%
result = None
print(result)
print("Type:", type(result))
# Out:
# None
# Type: <class 'NoneType'>

# %% [markdown]
# ### 2.8 Multiple Assignment
# Python allows you to assign multiple variables at once.

# %%
a=10
a=20
print(a)
# Out:
# 20

# %%
# Same value to multiple variables
a = b = c = 10
print(a, b, c)

# Different values in one line
name, age, city = "Bob", 30, "Mumbai"
print(name, age, city)

# Swapping values - Python magic!
x = 5
y = 10
x, y = y, x
print("After swap: x =", x, ", y =", y)
# Out:
# 10 10 10
# Bob 30 Mumbai
# After swap: x = 10 , y = 5

# %% [markdown]
# ---
# ## 3. Input and Output Functions
#
# ### 3.1 The `print()` Function

# %%
# Basic print
print("Hello!")

# Print multiple values - separated by spaces by default
print("My name is", "Alice", "and I am", 25)

# Using the 'sep' parameter to change separator
print("Apple", "Banana", "Cherry", sep=" | ")
print("2026", "01", "15", sep="-")
# Out:
# Hello!
# My name is Alice and I am 25
# Apple | Banana | Cherry
# 2026-01-15

# %% [markdown]
# ### 3.2 The `input()` Function
# Run this cell to be prompted for input.

# %%
# Get user input
name = input("What is your name? ")
print("Hello,", name + "!")
# Out:
# Hello, miraj!

# %%
# IMPORTANT: input() always returns a STRING!
age = input("Enter your age: ")
print("You entered:", age)
print("Type of age:", type(age))   # str, not int!

# Convert to integer to do math
age_int = int(age)
next_year_age = age_int+1
next_year_age
# Out:
# You entered: 26
# Type of age: <class 'str'>
# 27

# %%
# Get a number directly using int() with input()
num = int(input("Enter a number: "))
print("Square of", num, "is:", num ** 2)
# Out:
# Square of 2 is: 4

# %% [markdown]
# ---
# ## 4. format() Method, f-strings, & Escape Sequences
#
# ### 4.1 Old Way - String Concatenation

# %%
name = "Alice"
age = 25

# Concatenation - tedious and error-prone
# message = "My name is " + name + " and I am " + age + " years old." # This will raise a TypeError because age is an int, not a str
message = "My name is " + name + " and I am " + str(age) + " years old."
print(message)
# Out:
# My name is Alice and I am 25 years old.

# %% [markdown]
# ### 4.2 The `format()` Method

# %%
name = "Alice"
age = 25

# Using {} as placeholders (positional)
print("My name is {} and I am {} years old.".format(name, age))

# Using indexes
print("{0} is {1}. Yes, {0}!".format(name, age))

# Using named arguments
print("My name is {value1} and I am {value2} years old.".format(value1=name, value2=age))
# Out:
# My name is Alice and I am 25 years old.
# Alice is 25. Yes, Alice!
# My name is Alice and I am 25 years old.

# %%
pi = 3.141592653589793
new_pi = "{:.4f}".format(pi)
print(new_pi)
# Out:
# 3.1416

# %%
pi = 3.141592653589793
# print("{:.2f}".format(pi))
# print("{:.2f}".format(67882.378987))

num1 = "{:.2f}".format(67882.378987)

print(num1)
# Out:
# 67882.3790

# %%
# Number formatting with format()
pi = 3.141592653589793

print("Pi is {:.2f}".format(pi))         # 2 decimal places
print("Pi is {:.4f}".format(pi))         # 4 decimal places

print("Big number: {:,}".format(1234567))  # with commas

print("Padded: '{:>10}'".format("Hi"))    # right-aligned
print("Padded: '{:<10}'".format("Hi"))    # left-aligned
print("Padded: '{:^10}'".format("Hi"))    # centered
# Out:
# Pi is 3.14
# Pi is 3.1416
# Big number: 1,234,567
# Padded: '        Hi'
# Padded: 'Hi        '
# Padded: '    Hi    '

# %% [markdown]
# ### 4.3 f-strings (RECOMMENDED) - Python 3.6+

# %%
name = "Alice"
age = 25

# f-string - prefix with 'f' and embed variables inside {}
print(f"My name is {name} and I am {age} years old.")

# Expressions inside f-strings
print(f"Next year, I will be {age + 1}.")
print(f"In 5 years, I will be {age + 5}.")

# Calling methods inside f-strings
print(f"My name in uppercase: {name.upper()}")
print(f"Length of name: {len(name)}")
# Out:
# My name is Alice and I am 25 years old.
# Next year, I will be 26.
# In 5 years, I will be 30.
# My name in uppercase: ALICE
# Length of name: 5

# %%
pi = 3.141592653589793
print(f"{pi:.2f}")
# Out:
# 3.14

# %%
# f-string formatting
pi = 3.141592653589793
price = 1234.5678

print(f"Pi is {pi:.2f}")               # 3.14
print(f"Pi is {pi:.5f}")               # 3.14159

print(f"Price: ${price:.2f}")           # $1234.57
print(f"With commas: {1234567:,}")      # 1,234,567
# Out:
# Pi is 3.14
# Pi is 3.14159
# Price: $1234.57
# With commas: 1,234,567

# %%
# Creating a nice formatted table with f-strings
Name = "Alice"
Score = 95

Name1 = "Bob"
Score1 = 87

print(f"{'Name':<10} {'Score':>5}")
print("-" * 18)
print(f"{Name:<10} {Score:>5}")
print(f"{Name1:<10} {Score1:>5}")
# Out:
# Name       Score
# ------------------
# Alice         95
# Bob           87

# %% [markdown]
# ### 4.4 Escape Sequences

# %%
# \n - new line
print("Line 1\nLine 2\nLine 3")

print()  # blank line

# \t - tab
print("Name:\tAlice")
print("Age:\t25")
print("City:\tMumbai")
# Out:
# Line 1
# Line 2
# Line 3
#
# Name:	Alice
# Age:	25
# City:	Mumbai

# %%
print(r"C:\z_Learn\python_tutorial\test.ipynb")
# Out:
# C:\z_Learn\python_tutorial\test.ipynb

# %%
# \' and \" - escaping quotes
print('It\'s a beautiful day!')
print("She said, \"Hello!\"")

# \\ - backslash
print("File path: C:\\Users\\Alice\\Documents")
# Out:
# It's a beautiful day!
# She said, "Hello!"
# File path: C:\Users\Alice\Documents

# %%
# Raw strings - use 'r' prefix to ignore escape sequences
print(r"C:\Users\Alice\new_folder")        # printed as-is
print(r"\n is a newline character")        # \n is NOT processed
# Out:
# C:\Users\Alice\new_folder
# \n is a newline character

# %% [markdown]
# ---
# ## 5. Basic Arithmetic & Operators
#
# ### 5.1 Arithmetic Operators

# %%
a = 10
b = 3

print(f"a = {a}, b = {b}")
print(f"Addition:        a + b  = {a + b}")
print(f"Subtraction:     a - b  = {a - b}")
print(f"Multiplication:  a * b  = {a * b}")
print(f"Division:        a / b  = {a / b}")
print(f"Floor Division:  a // b = {a // b}")
print(f"Modulus:         a % b  = {a % b}")
print(f"Exponent:        a ** b = {a ** b}")
# Out:
# a = 10, b = 3
# Addition:        a + b  = 13
# Subtraction:     a - b  = 7
# Multiplication:  a * b  = 30
# Division:        a / b  = 3.3333333333333335
# Floor Division:  a // b = 3
# Modulus:         a % b  = 1
# Exponent:        a ** b = 1000

# %%
# Area of a rectangle
length = 10
width = 5
area = length * width
print(f"Area of rectangle: {area} sq units")

# Calculate total marks
math = 80
science = 75
english = 90
total_marks = math + science + english
print(f"Total Marks: {total_marks}")
# Out:
# Area of rectangle: 50 sq units
# Total Marks: 245

# %% [markdown]
# ### 5.2 Assignment Operators

# %%
x = 10
print("Initial x:", x)

x += 5      # x = x + 5
print("After x += 5:", x)

x -= 3      # x = x - 3
print("After x -= 3:", x)

x *= 2      # x = x * 2
print("After x *= 2:", x)

x /= 4      # x = x / 4
print("After x /= 4:", x)

x **= 2     # x = x ** 2
print("After x **= 2:", x)
# Out:
# Initial x: 10
# After x += 5: 15
# After x -= 3: 12
# After x *= 2: 24
# After x /= 4: 6.0
# After x **= 2: 36.0

# %% [markdown]
# ### 5.3 Comparison Operators (return True or False)

# %%
a = 10
b = 5

print(f"a == b: {a == b}")    # equal to
print(f"a != b: {a != b}")    # not equal to
print(f"a > b:  {a > b}")     # greater than
print(f"a < b:  {a < b}")     # less than
print(f"a >= b: {a >= b}")    # greater than or equal
print(f"a <= b: {a <= b}")    # less than or equal
# Out:
# a == b: False
# a != b: True
# a > b:  True
# a < b:  False
# a >= b: True
# a <= b: False

# %% [markdown]
# ### 5.4 Logical Operators

# %% [markdown]
# ### AND (`and`)
#
# | A | B | A and B |
# |---|---|----------|
# | True | True | True |
# | True | False | False |
# | False | True | False |
# | False | False | False |
#
# ### OR (`or`)
#
# | A | B | A or B |
# |---|---|---------|
# | True | True | True |
# | True | False | True |
# | False | True | True |
# | False | False | False |
#
# ### NOT (`not`)
#
# | A | not A |
# |---|-------|
# | True | False |
# | False | True |

# %%
age = 20
has_license = True
has_car = False

print("Can drive own car:", age >= 18 and has_license and has_car)
# Out:
# Can drive own car: False

# %%
print(f"Can drive own car: {age >= 18 and has_license and has_car}")
# Out:
# Can drive own car: False

# %%
age = 20
has_license = True
has_car = False

# 'and' - True if BOTH are True
print("Can drive own car:", age >= 18 and has_license and has_car)

# 'or' - True if AT LEAST ONE is True
print("Can use transportation:", has_car or has_license)

# 'not' - inverts the value
print("Doesn't have a car:", not has_car)

# Combining them
is_eligible = (age >= 18) and (has_license or has_car)
print("Is eligible:", is_eligible)
# Out:
# Can drive own car: False
# Can use transportation: True
# Doesn't have a car: True
# Is eligible: True

# %% [markdown]
# ### 5.5 Operator Precedence (PEMDAS)

# %%
# Without parentheses - multiplication before addition
print(2 + 3 * 4)        # 14, not 20

# With parentheses - addition first
print((2 + 3) * 4)      # 20

# Exponent has highest precedence (after parentheses)
print(2 ** 3 + 1)       # 9 (8 + 1)

# Tricky one - ** is right-associative
print(2 ** 3 ** 2)      # 512 (2 ** 9), NOT 64
# 3**2  -> 9
# 2**9  -> 512

# Complex expression
result = (10 + 5) * 2 - 8 / 4 + 3 ** 2
print(f"Result: {result}")  # 37.0
# Out:
# 14
# 20
# 9
# 512
# Result: 37.0

# %% [markdown]
# ### Expression
#
# ```python
# result = (10 + 5) * 2 - 8 / 4 + 3 ** 2
# ```
#
# ### Step-by-Step Calculation
#
# 1. Parentheses `()`
#
# ```python
# (10 + 5) = 15
# ```
#
# Expression becomes:
#
# ```python
# 15 * 2 - 8 / 4 + 3 ** 2
# ```
#
# 2. Exponent `**`
#
# ```python
# 3 ** 2 = 9
# ```
#
# Expression becomes:
#
# ```python
# 15 * 2 - 8 / 4 + 9
# ```
#
# 3. Multiplication `*`
#
# ```python
# 15 * 2 = 30
# ```
#
# Expression becomes:
#
# ```python
# 30 - 8 / 4 + 9
# ```
#
# 4. Division `/`
#
# ```python
# 8 / 4 = 2.0
# ```
#
# Expression becomes:
#
# ```python
# 30 - 2.0 + 9
# ```
#
# 5. Subtraction `-`
#
# ```python
# 30 - 2.0 = 28.0
# ```
#
# Expression becomes:
#
# ```python
# 28.0 + 9
# ```
#
# 6. Addition `+`
#
# ```python
# 28.0 + 9 = 37.0
# ```
#
# ### Final Result
#
# ```python
# result = 37.0
# ```

# %% [markdown]
# ---
# ## 6. Type Casting, Type Checking & Validation
#
# ### 6.1 Checking Types with `type()`

# %%
# Check the type of any value
print(type(42))            # int
print(type(3.14))          # float
print(type("hello"))       # str
print(type(True))          # bool
print(type(None))          # NoneType
print(type(3 + 4j))        # complex

# Check the type of variables
name = "Alice"
age = 25
height = 5.6

print(f"\nname is of type: {type(name)}")
print(f"age is of type:  {type(age)}")
print(f"height is of type: {type(height)}")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# <class 'complex'>
#
# name is of type: <class 'str'>
# age is of type:  <class 'int'>
# height is of type: <class 'float'>

# %% [markdown]
# ### 6.2 Type Casting (Converting Between Types)

# %%
# String to Integer
num_str = "42"
num_int = int(num_str)
print(f"'42' as int: {num_int}, type: {type(num_int)}")
print(f"Adding 8: {num_int + 8}")
# Out:
# '42' as int: 42, type: <class 'int'>
# Adding 8: 50

# %%
# String to Float
price_str = "19.99"
price = float(price_str)
print(f"Price: {price}, type: {type(price)}")
print(f"Double the price: {price * 2}")
# Out:
# Price: 19.99, type: <class 'float'>
# Double the price: 39.98

# %%
# Number to String
age = 25
age_str = str(age)
print(f"Type after str(): {type(age_str)}")

message = "I am " + age_str + " years old."
print(message)
# Out:
# Type after str(): <class 'str'>
# I am 25 years old.

# %%
# Float to Integer - TRUNCATES (cuts off decimals), doesn't round!
print(int(3.99))      # 3, not 4
print(int(3.01))      # 3
print(int(-3.99))     # -3, not -4
# Out:
# 3
# 3
# -3

# %%
# To round properly, use round()
print(round(3.99))    # 4
print(round(3.01))    # 3
print(round(3.5))     # 4
# Out:
# 4
# 3
# 4

# %%
# Integer to Float
x = 5
y = float(x)
print(f"{x} -> {y}")
print(f"Type: {type(y)}")
# Out:
# 5 -> 5.0
# Type: <class 'float'>

# %%
num = 0
type(num)
# Out:
# int

# %%
bool_con = bool(num)
bool_con
# Out:
# False

# %%
# Converting to Boolean
# 0, empty values, and None are falsy. Everything else is truthy.

print("bool(0):    ", bool(0))         # False
print("bool(1):    ", bool(1))         # True
print("bool(-5):   ", bool(-5))        # True (any non-zero number)
print("bool(''):   ", bool(""))        # False (empty string)
print("bool('hi'): ", bool("hi"))      # True
print("bool([]):   ", bool([]))        # False (empty list)
print("bool([0]):  ", bool([0]))       # True (non-empty list)
print("bool(None): ", bool(None))      # False
# Out:
# bool(0):     False
# bool(1):     True
# bool(-5):    True
# bool(''):    False
# bool('hi'):  True
# bool([]):    False
# bool([0]):   True
# bool(None):  False

# %% [markdown]
# ### 6.3 Type Checking with `isinstance()` (Preferred)

# %%
a =2.0
isinstance(a, str)
# Out:
# False

# %%
age = 25
name = "Alice"
price = 99.99

# Check single type
print(isinstance(age, int))            # True
print(isinstance(name, str))           # True
print(isinstance(age, str))            # False
# Out:
# True
# True
# False

# %%
# Check multiple types at once - use a tuple
print(isinstance(price, (int, float))) # True (price is a float)
print(isinstance(age, (int, float)))   # True (age is an int)
print(isinstance(name, (int, float)))  # False
# Out:
# True
# True
# False
